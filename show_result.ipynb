# %%
import q1_regression as q1

q1.result()
# Out:
#     Note:
#         The arg, k, to pass to function result()
#         means that there are k args in quadratic regression.
#         i.e. For k = 2,
#         the result returned is an array of two coefs.
#         That is, when k = 2, quadraic regression is equal to linear regression
#
# a. Linear Regression:
#
# 	The coefficients b and m for function (mx + b) is :
# 	b = 32.065
# 	m = -0.114
#
#
#
# b. Quadratic Regression(order = 2):
#
# 	For order k = 2
# 	coefficients are as below :
#
# 	a0 = 32.06539
# 	a1 = -0.11385
#
# b. Quadratic Regression(order = 6):
#
# 	For order k = 6
# 	coefficients are as below :
#
# 	a0 = 27.94605
# 	a1 = 2.87427
# 	a2 = -1.05487
# 	a3 = 0.19348
# 	a4 = -0.01462
# 	a5 = 0.00037

# %%
import q2_numerical as q2

q2.result()
# Out:
# Part1-1: Linear regression with fletcher_reeves
#
# 	The coefficients a0 and a1 for function (a0 + a1 * x) is :
# 	a0 = 32.065
# 	a1 = -0.114
#
# 	It cost 1.220 seconds.
#
#
#
# Part1-2: Quadratic regression with fletcher_reeves
#
# 	For order k = 3
# 	coefficients are as below:
#
# 	a0 = 30.48902
# 	a1 = 0.39218
# 	a2 = -0.02562
#
# 	It cost 14.364 seconds.
#
#
#
# Part1-3: Linear regression with DFP
#
# 	The coefficients a0 and a1 for function (a0 + a1 * x) is :
# 	a0 = 32.065
# 	a1 = -0.114
#
# 	It cost 0.032 seconds.
#
#
#
# Part1-2: Quadratic regression with fletcher_reeves
#
# 	For order k = 5
# 	coefficients are as below:
#
# 	a0 = 30.19683
# 	a1 = -2.54761
# 	a2 = 1.10135
# 	a3 = -0.11328
# 	a4 = 0.00328
#
# 	It cost 0.198 seconds.

# %%
import q3_suitable_order as q3

q3.result()
# Out:
# For order 7, loss = 131.518
# For order 8, loss = 82.899
# For order 9, loss = 76.911
# For order 10, loss = 67.158
# For order 11, loss = 37.294
# For order 12, loss = 104768.101
# For order 13, loss = 1990465.599
#
# The suitable order is : 11, which loss is : 37.294

# %%
import q4_myfunc as q4

q4.result()
# Out:
# [y_value] & [y_predict]
#   30.00 	29.12
#   27.00 	28.04
#   29.00 	29.44
#   30.00 	32.04
#   37.30 	34.38
#   36.40 	33.94
#   32.40 	32.67
#   28.50 	30.88
#   30.00 	31.78
#   34.10 	34.08
#   39.00 	36.24
#   36.00 	38.44
#   32.00 	32.57
#   28.00 	23.86
#   22.00 	22.64
#   20.00 	22.60
#   27.00 	25.85
#   40.00 	40.26
#
# loss = 69.307
